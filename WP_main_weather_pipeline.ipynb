# %% [markdown]
# ### Removing the residues

# %%
# %fs rm -r /user/hive/warehouse/
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res23: Boolean = true
# </div>

# %%
# %sql
drop table if exists log_table;
drop table if exists dim_date_table;
drop table if exists dim_time_table;
drop table if exists dim_city_table;
drop table if exists silver_weather_table;
drop table if exists bronze_weather_table;
drop table if exists fact_hourly_weather;
drop table if exists fact_daily_weather;
drop table if exists fact_hourly_table;
drop table if exists fact_daily_table;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %pip install python-dotenv
# Out:
# Python interpreter will be restarted.
# Requirement already satisfied: python-dotenv in /local_disk0/.ephemeral_nfs/envs/pythonEnv-11925a48-b78c-4468-8d43-9142dff49708/lib/python3.9/site-packages (1.0.0)
# Python interpreter will be restarted.

# %% [markdown]
# ### Loading all the functions to use in the main Pipeline

# %%
# %run "/Users/075bct068.roshan@pcampus.edu.np/WP_log_functions"

# %%
# %run "/Users/075bct068.roshan@pcampus.edu.np/WP_date_time_functions"

# %%
# %run "/Users/075bct068.roshan@pcampus.edu.np/WP_city_table_functions"

# %%
# %run "/Users/075bct068.roshan@pcampus.edu.np/WP_bronze_table _functions"

# %%
# %run "/Users/075bct068.roshan@pcampus.edu.np/WP_silver_table_fuctions"

# %%
# %run "/Users/075bct068.roshan@pcampus.edu.np/WP_gold_table_functions"

# %% [markdown]
# ### Creating the log table & decorator and loading all the dimension tables

# %%
create_log_table()
load_date_table()
load_time_table()
load_city_table()
# Out:
# /databricks/spark/python/pyspark/pandas/namespace.py:1881: FutureWarning: Argument `closed` is deprecated in favor of `inclusive`.
#   pd.date_range(

# %% [markdown]
# ### Processing and loading the bronze, silver and fact tables

# %%
raw_weather_df = extract_weather("RAW", "bronze_weather_table")
processed_weather_df = get_process_table("PROCESSED", "silver_weather_table", raw_weather_df)
fact_hourly_df = load_hourly_weather_data("FACT", "fact_hourly_weather", processed_weather_df)
fact_daily_df =load_daily_weather_data("FACT", "fact_daily_weather")

# %% [markdown]
# ### Viewing the data to ensure that the pipeline is working correctly

# %%
# %sql
SELECT * from bronze_weather_table;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>result</th><th>load_run_id</th><th>created_on</th><th>created_by</th></tr></thead><tbody><tr><td>List(10000, 20700, List(25.29, 24.74, 25.29, 25.29, 1004, 33, 1004, 918), List(null), List(NP, 1686266888, 1686316814), 1686248609, List(83.7667, 27.9833), Wāliṅ, List(List(801, Clouds, few clouds, 02n)), 200, 1282616, List(null, 330, 2.2), stations)</td><td>0a7ef8ed-179c-4497-8eb9-f2b6f050103c</td><td>2023-06-08T18:23:19.827+0000</td><td>Roshan Subedi</td></tr><tr><td>List(10000, 20700, List(24.79, 23.98, 24.79, 24.79, 1001, 25, 1001, 888), List(null), List(NP, 1686266726, 1686316592), 1686248603, List(84.5667, 27.7667), Upardang Gadhi, List(List(803, Clouds, broken clouds, 04n)), 200, 1282621, List(null, 57, 1.66), stations)</td><td>0a7ef8ed-179c-4497-8eb9-f2b6f050103c</td><td>2023-06-08T18:23:19.827+0000</td><td>Roshan Subedi</td></tr><tr><td>List(10000, 20700, List(27.05, 26.3, 27.05, 27.05, 1003, 26, 1003, 930), List(null), List(NP, 1686267221, 1686317186), 1686248607, List(82.2973, 28.131), Tulsīpur, List(List(800, Clear, clear sky, 01n)), 200, 1282635, List(null, 27, 1.99), stations)</td><td>0a7ef8ed-179c-4497-8eb9-f2b6f050103c</td><td>2023-06-08T18:23:19.827+0000</td><td>Roshan Subedi</td></tr><tr><td>List(10000, 20700, List(30.33, 28.68, 30.33, 30.33, 1000, 24, 1000, 978), List(null), List(NP, 1686266760, 1686316590), 1686248604, List(84.5, 27.6333), Tikoli, List(List(802, Clouds, scattered clouds, 03n)), 200, 1282665, List(null, 60, 1.57), stations)</td><td>0a7ef8ed-179c-4497-8eb9-f2b6f050103c</td><td>2023-06-08T18:23:19.827+0000</td><td>Roshan Subedi</td></tr><tr><td>List(10000, 20700, List(29.87, 28.2, 29.87, 29.87, 1000, 22, 1000, 982), List(null), List(NP, 1686267450, 1686317517), 1686248604, List(81.1333, 28.5), Ṭikāpur, List(List(800, Clear, clear sky, 01n)), 200, 1282666, List(null, 32, 1.87), stations)</td><td>0a7ef8ed-179c-4497-8eb9-f2b6f050103c</td><td>2023-06-08T18:23:19.827+0000</td><td>Roshan Subedi</td></tr><tr><td>List(10000, 20700, List(25.29, 24.74, 25.29, 25.29, 1004, 33, 1004, 918), List(null), List(NP, 1686266888, 1686316814), 1686248609, List(83.7667, 27.9833), Wāliṅ, List(List(801, Clouds, few clouds, 02n)), 200, 1282616, List(null, 330, 2.2), stations)</td><td>c57f73ff-86f0-48be-8343-d3451478d184</td><td>2023-06-08T18:26:19.732+0000</td><td>Roshan Subedi</td></tr><tr><td>List(10000, 20700, List(24.79, 23.98, 24.79, 24.79, 1001, 25, 1001, 888), List(null), List(NP, 1686266726, 1686316592), 1686248603, List(84.5667, 27.7667), Upardang Gadhi, List(List(803, Clouds, broken clouds, 04n)), 200, 1282621, List(null, 57, 1.66), stations)</td><td>c57f73ff-86f0-48be-8343-d3451478d184</td><td>2023-06-08T18:26:19.732+0000</td><td>Roshan Subedi</td></tr><tr><td>List(10000, 20700, List(27.05, 26.3, 27.05, 27.05, 1003, 26, 1003, 930), List(null), List(NP, 1686267221, 1686317186), 1686248607, List(82.2973, 28.131), Tulsīpur, List(List(800, Clear, clear sky, 01n)), 200, 1282635, List(null, 27, 1.99), stations)</td><td>c57f73ff-86f0-48be-8343-d3451478d184</td><td>2023-06-08T18:26:19.732+0000</td><td>Roshan Subedi</td></tr><tr><td>List(10000, 20700, List(30.33, 28.68, 30.33, 30.33, 1000, 24, 1000, 978), List(null), List(NP, 1686266760, 1686316590), 1686248604, List(84.5, 27.6333), Tikoli, List(List(802, Clouds, scattered clouds, 03n)), 200, 1282665, List(null, 60, 1.57), stations)</td><td>c57f73ff-86f0-48be-8343-d3451478d184</td><td>2023-06-08T18:26:19.732+0000</td><td>Roshan Subedi</td></tr><tr><td>List(10000, 20700, List(29.87, 28.2, 29.87, 29.87, 1000, 22, 1000, 982), List(null), List(NP, 1686267450, 1686317517), 1686248604, List(81.1333, 28.5), Ṭikāpur, List(List(800, Clear, clear sky, 01n)), 200, 1282666, List(null, 32, 1.87), stations)</td><td>c57f73ff-86f0-48be-8343-d3451478d184</td><td>2023-06-08T18:26:19.732+0000</td><td>Roshan Subedi</td></tr><tr><td>List(10000, 20700, List(25.29, 24.74, 25.2 ...

# %%
# %sql
SELECT * from silver_weather_table;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>

# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>city_id</th><th>date_key</th><th>temperature</th><th>minimum_temperature</th><th>maximum_temperature</th><th>pressure</th><th>humidity</th><th>visibility</th><th>wind_speed</th><th>wind_degree</th><th>wind_gust</th><th>clouds_all</th><th>load_run_id</th><th>created_on</th><th>created_by</th></tr></thead><tbody><tr><td>1282635</td><td>20230608</td><td>27.049999237060547</td><td>27.05</td><td>27.05</td><td>1003</td><td>26</td><td>10000</td><td>null</td><td>27</td><td>1.9900000095367432</td><td>null</td><td>ce77a855-ce84-430e-ac79-44551d6e585b</td><td>2023-06-08T18:27:24.848+0000</td><td>Roshan Subedi</td></tr><tr><td>1282621</td><td>20230608</td><td>24.790000915527344</td><td>24.79</td><td>24.79</td><td>1001</td><td>25</td><td>10000</td><td>null</td><td>57</td><td>1.659999966621399</td><td>null</td><td>ce77a855-ce84-430e-ac79-44551d6e585b</td><td>2023-06-08T18:27:24.848+0000</td><td>Roshan Subedi</td></tr><tr><td>1282616</td><td>20230608</td><td>25.290000915527344</td><td>25.29</td><td>25.29</td><td>1004</td><td>33</td><td>10000</td><td>null</td><td>330</td><td>2.200000047683716</td><td>null</td><td>ce77a855-ce84-430e-ac79-44551d6e585b</td><td>2023-06-08T18:27:24.848+0000</td><td>Roshan Subedi</td></tr><tr><td>1282665</td><td>20230608</td><td>30.329999923706055</td><td>30.33</td><td>30.33</td><td>1000</td><td>24</td><td>10000</td><td>null</td><td>60</td><td>1.5700000524520874</td><td>null</td><td>ce77a855-ce84-430e-ac79-44551d6e585b</td><td>2023-06-08T18:27:24.848+0000</td><td>Roshan Subedi</td></tr><tr><td>1282666</td><td>20230608</td><td>29.8700008392334</td><td>29.87</td><td>29.87</td><td>1000</td><td>22</td><td>10000</td><td>null</td><td>32</td><td>1.8700000047683716</td><td>null</td><td>ce77a855-ce84-430e-ac79-44551d6e585b</td><td>2023-06-08T18:27:24.848+0000</td><td>Roshan Subedi</td></tr></tbody></table></div>

# %%
# %sql
SELECT * from log_table;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>load_type</th><th>table_name</th><th>process_start_time</th><th>process_end_time</th><th>status</th><th>comments</th><th>start_date_time</th><th>end_date_time</th><th>created_on</th><th>created_by</th></tr></thead><tbody><tr><td>95b23437-e3b8-49fa-9b3b-abe00ddf2841</td><td>PROCESSED</td><td>silver_weather_table</td><td>2023-06-08T18:26:37.494+0000</td><td>2023-06-08T18:26:50.018+0000</td><td>COMPLETED</td><td>null</td><td>2023-06-08T18:23:23.000+0000</td><td>2023-06-08T18:23:27.000+0000</td><td>2023-06-08T18:26:37.494+0000</td><td>Roshan Subedi</td></tr><tr><td>3454930b-9afa-43eb-80f8-9ffe05d3ac5f</td><td>PROCESSED</td><td>silver_weather_table</td><td>2023-06-08T18:24:53.588+0000</td><td>2023-06-08T18:25:08.538+0000</td><td>COMPLETED</td><td>null</td><td>2023-06